# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
MODEL = os.getenv("CHAT_MODEL")

# %%
from langchain.chat_models import init_chat_model
model=init_chat_model(MODEL)
model
# Out:
# ChatOpenAI(metadata={'lc_versions': {'langchain-core': '1.5.4', 'langchain': '1.3.15', 'langchain-openai': '1.4.3'}}, profile={'name': 'GPT-5.4 nano', 'release_date': '2026-03-17', 'last_updated': '2026-03-17', 'open_weights': False, 'max_input_tokens': 400000, 'max_output_tokens': 128000, 'text_inputs': True, 'image_inputs': True, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': True, 'tool_calling': True, 'structured_output': True, 'attachment': True, 'temperature': False, 'image_url_inputs': True, 'pdf_inputs': True, 'pdf_tool_message': True, 'image_tool_message': True, 'tool_choice': True, 'tool_call_streaming': True, 'reasoning_effort_levels': ['none', 'low', 'medium', 'high', 'xhigh']}, client=<openai.resources.chat.completions.completions.Completions object at 0x0000021DF6698860>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x0000021DF5E27FB0>, root_client=<openai.OpenAI object at 0x0000021DF6692870>, root_async_client=<openai.AsyncOpenAI object at 0x0000021DF669A510>, model_name='gpt-5.4-nano', model_kwargs={}, openai_api_key=SecretStr('**********'), stream_usage=True, stream_chunk_timeout=120.0)

# %%
response=model.invoke("Hello How are you?")
response
# Out:
# AIMessage(content='Hello! I’m doing well—thanks for asking 😊  \nHow are you today?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 20, 'prompt_tokens': 11, 'total_tokens': 31, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-EBo5j8umXQl4yOLRyDJVHbeQXtgzh', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ff2ad-38dd-7300-8851-8094c898265d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 20, 'total_tokens': 31, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# #### Streaming

# %%
for chunk in model.stream("Write me a 200 words paragraph on Artificial Intelligence"):
    print(chunk.text, end="|", flush=True)
# Out:
# |Artificial| Intelligence| (|AI|)| is| a| technology| that| enables| machines| to| perform| tasks| that| normally| require| human| intelligence|.| These| tasks| can| include| understanding| language|,| recognizing| images|,| learning| from| data|,| and| making| decisions|.| AI| systems| are| often| built| using| algorithms| and| large| amounts| of| information|,| allowing| them| to| identify| patterns| and| improve| their| performance| over| time|.| For| example|,| recommendation| systems| in| streaming| services| use| AI| to| suggest| movies| or| music| based| on| a| user|’s| past| behavior|.| In| healthcare|,| AI| can| help| analyze| medical| images| and| support| doctors| by| detecting| signs| of| diseases| earlier| than| traditional| methods| might|.| Despite| its| benefits|,| AI| also| raises| important| concerns|,| such| as| privacy|,| bias|,| and| job| displacement|.| If| the| data| used| to| train| AI| is| incomplete| or| unfair|,| the| system| may| produce| biased| results|.| Additionally|,| as| AI| becomes| more| capable|,| society| must| consider| how| to| use| it| responsibly| and| ethically|.| Overall|,| AI| is| transforming| daily| life| and| industries|,| offering| new| opportunities| while| requiring| careful| guidance| to| ensure| it| serves| people| in| a| safe| and| beneficial| way|.||||

# %% [markdown]
# ### Batch

# %%
model.batch(
    ["Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"],
    config={
        'max_concurrency': 5,  # Limit to 5 parallel calls
    }
)
# Out:
# [AIMessage(content='Parrots have colorful feathers mainly because of **evolution**, **communication**, and **specialized feather structures**:\n\n- **Mate attraction and signaling:** Bright colors help parrots show health and genetic quality to potential mates, making them more likely to reproduce. They can also signal readiness to breed.\n- **Species and social communication:** Color patterns help parrots recognize members of the same species, and may convey information within flocks.\n- **Camouflage and survival:** Some bright coloration can also help with blending into specific environments (like colorful tropical foliage) or with intimidation/avoidance of predators.\n- **Feather microstructure (iridescence):** Many parrot colors—especially blues and greens—aren’t just pigments. They come from **microscopic feather structures** that refract light, producing vivid hues without large amounts of pigment.\n- **Diet and pigments:** Some colors (like reds and yellows) come from pigments such as carotenoids, which parrots acquire from their diet. Health and diet can affect how vivid the colors look.\n\nOverall, the colors are the result of natural selection shaping traits that help parrots survive and reproduce.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 235, 'prompt_tokens': 14, 'total_tokens': 249, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-EBo8z6vyqPkkJS8tgkZ7tjOaapVGn', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ff2b0-4cdd-77a1-afcb-edaa1705fddc-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 14, 'output_tokens': 235, 'total_tokens': 249, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='Airplanes fly because their wings generate **lift**.\n\n- **Forward motion:** When the plane moves through the air, air flows faster over the curved shape of the wing.\n- **Lower pressure on top / higher pressure underneath:** This creates a pressure difference that pushes the wing **up**—that upward force is **lift**.\n- **Balance of forces:** For the plane to keep flying, lift needs to be strong enough to balance the plane’s weight, while:\n  - **Thrust** (from the engines) pushes the plane forward\n  - **Drag** (air resistance) tries to slow it down\n\nPut together: **Lift up + Weight down** (balanced) and **Thrust forward + Drag back** (balanced or at least thrust is greater to speed up).', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 163, 'prompt_tokens': 11, 'total_tokens': 174, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-EBo8zcAL0Culn1gcW8C8vL2x1nLX3', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ff2b0-4cef-7c61-a125-c54795058bb5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 163, 'total_tokens': 174, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='Quantum computing is a type of computing that uses the principles of **quantum mechanics** (the physics of very small things) to process information.\n\n### Key idea\n- In a **classical computer**, information is stored in **bits** that are either **0 or 1**.\n- In a **quantum computer**, information is stored in **quantum bits (qubits)** that can be in a **superposition** of states—meaning they can be 0, 1, or a mix of both at the same time (until measured).\n- Qubits can also be **entangled**, meaning the state of one qubit is linked to another, even across distance.\n\n### Why it can be faster (for some problems)\nQuantum algorithms can exploit **superposition** and **entanglement** to explore many possibilities at once and then use **interference** to amplify the correct answers. This can provide big speedups for certain tasks.\n\n### Where it may help\nQuantum computing is promising for problems like:\n- **Cryptography** (e.g., breaking certain encryption schemes, in theory)\n- **Chemistry and materials** (simulating molecules and materials more naturally)\n- **Optimization** and certain **search** problems\n- Some types of **machine learning** and **physics simulations**\n\n### Important limits\n- Quantum computers are still **early-stage** and require extremely controlled conditions (often very cold environments).\n- They suffer from **noise** and **errors**, so practical large-scale quantum computing needs **quantum error correction**.\n- They are not expected to replace classical computers for everything; they’re best seen as complementary.\n\nIf you want, I can explain how qubits work in more intuitive terms or give a couple of real-world examples of quantum algorithms.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 363, 'prompt_tokens': 11, 'total_tokens': 374, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cache_write_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-nano-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-EBo8zBWnb5QrIYxgMRM2lYf51wphR', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019ff2b0-4cf5-7240-b1b2-b700ce10416b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 11, 'output_tokens': 363, 'total_tokens': 374, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]
